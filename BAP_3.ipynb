# %% [markdown]
# Name - Vedanti Anil Wadatkar
# UID - 2021700072
# Batch - CSE DS (F)

# %%
import pandas as pd
import numpy as np
df = pd.read_csv(r"C:\Users\user\Desktop\numpy\flipkart_smartphones.csv")
df
# Out:
#       brand             model               colour  original_price  \
# 0      VIVO      VIVO T1 44W            Starry Sky           19990
# 1     APPLE  APPLE IPHONE 11                 White           48900
# 2      VIVO      VIVO T1 44W       Midnight Galaxy           20990
# 3    XIAOMI       POCO M4 5G           Power Black           15999
# 4    XIAOMI         REDMI 10       Caribbean Green           14999
# ..      ...               ...                  ...             ...
# 831  REALME  REALME GT NEO 2              NEO Blue           38999
# 832  REALME  REALME GT NEO 2             NEO Black           38999
# 833  REALME  REALME GT NEO 2             NEO Black           34999
# 834  REALME   REALME X50 PRO              Rust Red           17999
# 835  XIAOMI      POCO M2 PRO   Two Shades of Black           17999
#
#      discounted_price  ratings  rating_count  reviews  memory  storage  \
# 0               14499      4.5         87331     6044     4.0    128.0
# ...

# %%
import random
data = {
    'Attribute1': [random.randint(1, 100) for _ in range(20)],
    'Attribute2': [random.uniform(0.0, 1.0) for _ in range(20)],
    'Attribute3': [chr(random.randint(65, 90)) for _ in range(20)],
    'Attribute4': [random.choice(['Category1', 'Category2', 'Category3']) for _ in range(20)]
}
df_1 = pd.DataFrame(data)
print(df_1)
# Out:
#     Attribute1  Attribute2 Attribute3 Attribute4
# 0           74    0.623501          G  Category2
# 1           25    0.310391          C  Category3
# 2           26    0.640644          L  Category1
# 3           58    0.767845          G  Category3
# 4           46    0.634323          J  Category2
# 5           74    0.084558          X  Category2
# 6           97    0.658941          D  Category2
# 7           24    0.615123          H  Category3
# 8           67    0.845813          V  Category1
# 9           50    0.762221          O  Category2
# 10          64    0.756750          U  Category1
# 11           4    0.920805          C  Category2
# 12         100    0.352127          Y  Category1
# 13          89    0.198354          E  Category1
# 14          54    0.499458          E  Category1
# 15          56    0.125439          T  Category3
# 16          13    0.140113          Z  Category2
# 17          11    0.195326          M  Category2
# ...

# %% [markdown]
# ### Concatenating DataFrames

# %%
df_2 = df[['model']].iloc[:20]
df_2
# Out:
#                    model
# 0           VIVO T1 44W
# 1       APPLE IPHONE 11
# 2           VIVO T1 44W
# 3            POCO M4 5G
# 4              REDMI 10
# 5            POCO M4 5G
# 6              POCO C31
# 7            POCO M4 5G
# 8              REDMI 10
# 9           VIVO T1 44W
# 10          VIVO T1 44W
# 11  INFINIX HOT 20 PLAY
# 12  INFINIX HOT 20 PLAY
# 13  INFINIX HOT 20 PLAY
# 14       REDMI 9I SPORT
# 15  INFINIX HOT 20 PLAY
# 16             POCO C31
# 17             POCO C31
# 18      APPLE IPHONE 11
# 19         MOTOROLA G52

# %%
# Concatenating along columns (axis=1)
result_1 = pd.concat([df_1, df_2], axis=1)
result_1
# Out:
#     Attribute1  Attribute2 Attribute3 Attribute4                 model
# 0           74    0.623501          G  Category2          VIVO T1 44W
# 1           25    0.310391          C  Category3      APPLE IPHONE 11
# 2           26    0.640644          L  Category1          VIVO T1 44W
# 3           58    0.767845          G  Category3           POCO M4 5G
# 4           46    0.634323          J  Category2             REDMI 10
# 5           74    0.084558          X  Category2           POCO M4 5G
# 6           97    0.658941          D  Category2             POCO C31
# 7           24    0.615123          H  Category3           POCO M4 5G
# 8           67    0.845813          V  Category1             REDMI 10
# 9           50    0.762221          O  Category2          VIVO T1 44W
# 10          64    0.756750          U  Category1          VIVO T1 44W
# 11           4    0.920805          C  Category2  INFINIX HOT 20 PLAY
# ...

# %%
# Concatenating along columns (axis=0)
result_2 = pd.concat([df_1, df_2], axis=0)
result_2
# Out:
#     Attribute1  Attribute2 Attribute3 Attribute4                 model
# 0         74.0    0.623501          G  Category2                   NaN
# 1         25.0    0.310391          C  Category3                   NaN
# 2         26.0    0.640644          L  Category1                   NaN
# 3         58.0    0.767845          G  Category3                   NaN
# 4         46.0    0.634323          J  Category2                   NaN
# 5         74.0    0.084558          X  Category2                   NaN
# 6         97.0    0.658941          D  Category2                   NaN
# 7         24.0    0.615123          H  Category3                   NaN
# 8         67.0    0.845813          V  Category1                   NaN
# 9         50.0    0.762221          O  Category2                   NaN
# 10        64.0    0.756750          U  Category1                   NaN
# 11         4.0    0.920805          C  Category2                   NaN
# ...

# %% [markdown]
# ### Merging Dataframes

# %%
#merge on key 'model'
result_3 = df.iloc[:20]
result_3
# Out:
#        brand                 model           colour  original_price  \
# 0       VIVO          VIVO T1 44W        Starry Sky           19990
# 1      APPLE      APPLE IPHONE 11             White           48900
# 2       VIVO          VIVO T1 44W   Midnight Galaxy           20990
# 3     XIAOMI           POCO M4 5G       Power Black           15999
# 4     XIAOMI             REDMI 10   Caribbean Green           14999
# 5     XIAOMI           POCO M4 5G         Cool Blue           15999
# 6     XIAOMI             POCO C31       Shadow Gray           11999
# 7     XIAOMI           POCO M4 5G            Yellow           15999
# 8     XIAOMI             REDMI 10    Midnight Black           14999
# 9       VIVO          VIVO T1 44W   Midnight Galaxy           23990
# 10      VIVO          VIVO T1 44W        Starry Sky           20990
# 11   INFINIX  INFINIX HOT 20 PLAY      Racing Black           11999
# 12   INFINIX  INFINIX HOT 20 PLAY         Luna Blue           11999
# ...

# %%
merged_result = result_1.merge(result_2, on='model')
merged_result
# Out:
#     Attribute1_x  Attribute2_x Attribute3_x Attribute4_x  \
# 0             74      0.623501            G    Category2
# 1             74      0.623501            G    Category2
# 2             74      0.623501            G    Category2
# 3             74      0.623501            G    Category2
# 4             26      0.640644            L    Category1
# 5             26      0.640644            L    Category1
# 6             26      0.640644            L    Category1
# 7             26      0.640644            L    Category1
# 8             50      0.762221            O    Category2
# 9             50      0.762221            O    Category2
# 10            50      0.762221            O    Category2
# 11            50      0.762221            O    Category2
# 12            64      0.756750            U    Category1
# 13            64      0.756750            U    Category1
# 14            64      0.756750            U    Category1
# ...

# %% [markdown]
# ### Stack and Unstack

# %%
stack_df = df.stack()
stack_df
# Out:
# 0    brand                                  VIVO
#      model                          VIVO T1 44W
#      colour                           Starry Sky
#      original_price                        19990
#      discounted_price                      14499
#                                   ...
# 835  rear_camera         48MP + 8MP + 5MP + 2MP
#      front_camera                           16MP
#      display_size                          16.94
#      battery_capacity                     5000.0
#      battery_type                        Lithium
# Length: 12592, dtype: object

# %%
unstack_df=stack_df.unstack()
unstack_df
# Out:
#       brand             model               colour original_price  \
# 0      VIVO      VIVO T1 44W            Starry Sky          19990
# 1     APPLE  APPLE IPHONE 11                 White          48900
# 2      VIVO      VIVO T1 44W       Midnight Galaxy          20990
# 3    XIAOMI       POCO M4 5G           Power Black          15999
# 4    XIAOMI         REDMI 10       Caribbean Green          14999
# ..      ...               ...                  ...            ...
# 831  REALME  REALME GT NEO 2              NEO Blue          38999
# 832  REALME  REALME GT NEO 2             NEO Black          38999
# 833  REALME  REALME GT NEO 2             NEO Black          34999
# 834  REALME   REALME X50 PRO              Rust Red          17999
# 835  XIAOMI      POCO M2 PRO   Two Shades of Black          17999
#
#     discounted_price ratings rating_count reviews memory storage  \
# 0              14499     4.5        87331    6044    4.0   128.0
# ...

# %% [markdown]
# ### Pivot

# %%
duplicates = df[df.duplicated(subset='brand', keep=False)]

df = df.drop_duplicates(subset='brand', keep='first')

pivot_df = df.pivot(index='brand', columns='model', values=['colour', 'storage'])
print(pivot_df)
# Out:
#                    colour                                  \
# model    APPLE IPHONE 11  GOOGLE PIXEL 6A  I KALL Z19PRO
# brand
# APPLE               White              NaN            NaN
# GOOGLE                NaN            Chalk            NaN
# I KALL                NaN              NaN           Blue
# INFINIX               NaN              NaN            NaN
# IQOO                  NaN              NaN            NaN
# ITEL                  NaN              NaN            NaN
# LAVA                  NaN              NaN            NaN
# MARQ                  NaN              NaN            NaN
# MICROMAX              NaN              NaN            NaN
# MOTOROLA              NaN              NaN            NaN
# NOKIA                 NaN              NaN            NaN
# NOTHING               NaN              NaN            NaN
# ONEPLUS               NaN              NaN            NaN
# OPPO                  NaN              NaN            NaN
# ...

# %% [markdown]
# 1) Groupby

# %%
grouped_df = df.groupby(['brand', 'model']).sum().reset_index()
print("\nDataFrame after grouping and aggregation:")
print(grouped_df)
# Out:
# DataFrame after grouping and aggregation:
#        brand                       model          colour  original_price  \
# 0      APPLE            APPLE IPHONE 11            White           48900
# 1     GOOGLE            GOOGLE PIXEL 6A            Chalk           43999
# 2     I KALL              I KALL Z19PRO             Blue           10499
# 3    INFINIX        INFINIX HOT 20 PLAY     Racing Black           11999
# 4       IQOO                IQOO Z6 44W      Raven Black           17999
# 5       ITEL               ITEL VISION3       Jewel Blue            7999
# 6       LAVA             LAVA BLAZE PRO     Glass Orange           12999
# 7       MARQ  MARQ BY FLIPKART M3 SMART                             7999
# 8   MICROMAX             MICROMAX IN 2C           Silver            9499
# 9   MOTOROLA               MOTOROLA G52    Charcoal Grey           17999
# 10     NOKIA             NOKIA G11 PLUS             Grey           13999
# ...
