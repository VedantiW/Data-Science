# %% [markdown]
# NAME- Vedanti Wadatakar
# UID - 2021700072
# BATCH - TE CSE DATA SCIENCE
# BAP BATCH F

# %%
import pandas as pd
df=pd.read_csv(r'C:\Users\user\Desktop\numpy\flipkart_smartphones.csv')
df.head()
# Out:
#     brand             model           colour  original_price  \
# 0    VIVO      VIVO T1 44W        Starry Sky           19990
# 1   APPLE  APPLE IPHONE 11             White           48900
# 2    VIVO      VIVO T1 44W   Midnight Galaxy           20990
# 3  XIAOMI       POCO M4 5G       Power Black           15999
# 4  XIAOMI         REDMI 10   Caribbean Green           14999
#
#    discounted_price  ratings  rating_count  reviews  memory  storage  \
# 0             14499      4.5         87331     6044     4.0    128.0
# 1             47199      4.6        184191    10818     NaN    128.0
# 2             15999      4.4         51365     3750     6.0    128.0
# 3             11999      4.2         53448     4185     4.0     64.0
# 4              9299      4.3        187787    12084     4.0     64.0
#
#                  processor        rear_camera front_camera  display_size  \
# 0  Qualcomm Snapdragon 680  50MP + 2MP + 2MP          16MP         16.36
# ...

# %%
df.to_excel('output.xlsx') # pandas dataframe to excel conversion

# %%
df1=pd.read_json(r'C:\Users\user\Desktop\numpy\json.json')
df1.head()
# Out:
#                                               states
# 0  {'state': {'state_id': 'AN', 'state_name': 'An...
# 1  {'state': {'state_id': 'AP', 'state_name': 'An...
# 2  {'state': {'state_id': 'AR', 'state_name': 'Ar...
# 3  {'state': {'state_id': 'AS', 'state_name': 'As...
# 4  {'state': {'state_id': 'BR', 'state_name': 'Bi...

# %%
import matplotlib.pyplot as plt
df['original_price'].hist() 
#simple hist plot for og price column
# Out:
# <Axes: >

# %%
plt.plot(df['original_price'],df['discounted_price'])
plt.show()
#simple plot - no insights can be taken

# %%
df2 = df[['discounted_price', 'original_price']]
df2.plot.line()
#line plot of original prices vs discounted prices
# Out:
# <Axes: >

# %%
df2 = df[['discounted_price', 'original_price']].iloc[:15]
df2.plot.line()
#zoom in of earlier graph for 15 samples to see the relationship between og price and discounted price
# Out:
# <Axes: >

# %%
#we can get the visual for number of brands of smartphones in the dataset using pie chart
df3=df['brand'].value_counts()
df3.plot.pie()
# Out:
# <Axes: ylabel='count'>

# %%
plt.figure(figsize=(8, 6))
reviews=df['reviews'].iloc[:15]
rating=df['ratings'].iloc[:15]
plt.scatter(reviews,rating, color='blue', alpha=0.7)
plt.title('Number of Reviews vs Ratings')
plt.xlabel('Number of Reviews')
plt.ylabel('Ratings')
plt.grid(True)
plt.show()
